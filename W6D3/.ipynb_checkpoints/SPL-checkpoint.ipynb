# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/02 04:21:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6e4e9b433d55:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.option("header","true").option("inferSchema","true").csv("/home/kasm-user/Desktop/Downloads/iot_sensor_data.csv")

# %%
df.show()
# Out:
# +---------+-----------+-----------+-----------+--------+------+
# |sensor_id|   location|device_type|temperature|humidity|status|
# +---------+-----------+-----------+-----------+--------+------+
# |        1|    Plant_D|Thermometer|         66|      58|    OK|
# |        2|  Factory_B|Thermometer|         71|      56|    OK|
# |        3|    Plant_C|Thermometer|         92|      36|  FAIL|
# |        4|  Factory_A|Thermometer|         78|      42|    OK|
# |        5|  Factory_A|Thermometer|         99|      48|  FAIL|
# |        6|  Factory_B| Hygrometer|         78|      62|    OK|
# |        7|  Factory_A|Thermometer|         92|      45|  FAIL|
# |        8|Warehouse_A|Thermometer|         78|      65|    OK|
# |        9|  Factory_A|Thermometer|         89|      38|    OK|
# |       10|Warehouse_A| Hygrometer|         85|      47|    OK|
# |       11|    Plant_C|Thermometer|         89|      37|    OK|
# |       12|    Plant_D| Hygrometer|         78|      57|    OK|
# ...

# %%
df_temp=df.withColumn("temperature_fahrenheit",(df.temperature*9/5)+32)

# %%
df_temp.show()
# Out:
# +---------+-----------+-----------+-----------+--------+------+----------------------+
# |sensor_id|   location|device_type|temperature|humidity|status|temperature_fahrenheit|
# +---------+-----------+-----------+-----------+--------+------+----------------------+
# |        1|    Plant_D|Thermometer|         66|      58|    OK|                 150.8|
# |        2|  Factory_B|Thermometer|         71|      56|    OK|                 159.8|
# |        3|    Plant_C|Thermometer|         92|      36|  FAIL|                 197.6|
# |        4|  Factory_A|Thermometer|         78|      42|    OK|                 172.4|
# |        5|  Factory_A|Thermometer|         99|      48|  FAIL|                 210.2|
# |        6|  Factory_B| Hygrometer|         78|      62|    OK|                 172.4|
# |        7|  Factory_A|Thermometer|         92|      45|  FAIL|                 197.6|
# |        8|Warehouse_A|Thermometer|         78|      65|    OK|                 172.4|
# ...

# %%
df_cast=df.withColumn("temperature",df.temperature.cast("double"))

# %%
df_cast.printSchema()
# Out:
# root
#  |-- sensor_id: integer (nullable = true)
#  |-- location: string (nullable = true)
#  |-- device_type: string (nullable = true)
#  |-- temperature: double (nullable = true)
#  |-- humidity: integer (nullable = true)
#  |-- status: string (nullable = true)

# %%
from pyspark.sql.functions import sum

# %%
df.select(sum("temperature")).show()
# Out:
# +----------------+
# |sum(temperature)|
# +----------------+
# |           39537|
# +----------------+

# %%
from pyspark.sql.functions import avg

# %%
df.select(avg("temperature")).show()
# Out:
# +----------------+
# |avg(temperature)|
# +----------------+
# |          79.074|
# +----------------+

# %%
from pyspark.sql.functions import min

# %%
df.select(min("temperature")).show()
# Out:
# +----------------+
# |min(temperature)|
# +----------------+
# |              60|
# +----------------+

# %%
from pyspark.sql.functions import max

# %%
df.select(max("temperature")).show()
# Out:
# +----------------+
# |max(temperature)|
# +----------------+
# |             100|
# +----------------+
